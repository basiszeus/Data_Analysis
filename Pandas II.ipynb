# %% [markdown]
# <center><h1 style="background-color: #C6F3CD; border-radius: 10px; color: #FFFFFF; padding: 5px;">
# Data Management
# </h1><center/>

# %% [markdown]
# **Link to the article** :  https://medium.com/@soulawalid/pandas-tutorial-ii-2024-update-1a5d6ca4ddb3?sk=351936372ab69dfa59b1f1199124fea0

# %%
import pandas as pd

# %%
# lOAD a DataFrame
bios = pd.read_excel(r'C:\Users\Walid\Desktop\olympics-data.xlsx')
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
# If you want to acces specific sheet you can use the following
results = pd.read_excel(r'C:\Users\Walid\Desktop\olympics-data.xlsx', sheet_name = 'results')
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
# Save to another format
results.to_parquet('C:/Users/Walid/Desktop/new file.parquet')
# Read it
results2 = pd.read_parquet(r'C:\Users\Walid\Desktop\new file.parquet')
results2
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
# Access a sample of the data
results2.sample(10)
# Out:
#           year    type               discipline  \
# 24184   1988.0  Summer  Cycling Track (Cycling)
# 265161  2012.0  Summer  Basketball (Basketball)
# 134039  1988.0  Summer                Athletics
# 29892   1988.0  Summer   Cycling Road (Cycling)
# 111872  1992.0  Summer      Swimming (Aquatics)
# 84492   1980.0  Summer                   Rowing
# 137038  1924.0  Summer                Athletics
# 242651  2012.0  Summer                   Boxing
# 292822  2022.0  Winter  Ice Hockey (Ice Hockey)
# 150366  1936.0  Summer                Athletics
#
#                                               event                 as  \
# 24184     Team Pursuit, 4,000 metres, Men (Olympic)      Fabio Baldato
# 265161                  Basketball, Women (Olympic)  Tássia Carcavalli
# 134039          4 × 100 metres Relay, Men (Olympic)       James Browne
# 29892          Road Race, Individual, Men (Olympic)           Uwe Raab
# 111872  200 metres Individual Medley, Men (Olympic)        Jan Bidrman
# ...

# %%
# Consistant sample
results2.sample((10),random_state =1)
# Out:
#           year    type                        discipline  \
# 288565  2020.0  Summer                            Boxing
# 57866   1972.0  Summer  Artistic Gymnastics (Gymnastics)
# 62957   1952.0  Summer  Artistic Gymnastics (Gymnastics)
# 269319  2012.0  Summer             Water Polo (Aquatics)
# 62254   1908.0  Summer  Artistic Gymnastics (Gymnastics)
# 269358  2016.0  Summer                         Athletics
# 75029   1996.0  Summer                          Handball
# 19642   1960.0  Summer   Equestrian Jumping (Equestrian)
# 165394  1920.0  Summer                         Athletics
# 59966   1984.0  Summer  Artistic Gymnastics (Gymnastics)
#
#                                          event                  as  \
# 288565                Flyweight, Men (Olympic)          Yoel Finol
# 57866          Floor Exercise, Women (Olympic)         Cathy Rigby
# 62957            Horizontal Bar, Men (Olympic)        Frank Turner
# ...

# %%
# Loc
results2.loc[0]
# Out:
# year                          1912.0
# type                          Summer
# discipline                    Tennis
# event         Singles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                            None
# place                           17.0
# tied                            True
# medal                           None
# Name: 0, dtype: object

# %%
# Multiple Loc
results2.loc[[0,1,3]]
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None

# %%
# Slice
results2.loc[0:3]
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None

# %%
# Slide with rows and columns with loc
results2.loc[0:2, ['type','team']]
# Out:
#      type            team
# 0  Summer            None
# 1  Summer  Jean Montariol
# 2  Summer            None

# %%
# All rows and specific columns with loc
results2.loc[:, ['type','team']]
# Out:
#           type             team
# 0       Summer             None
# 1       Summer   Jean Montariol
# 2       Summer             None
# 3       Summer  Jeanne Vaussard
# 4       Summer  Jacques Brugnon
# ...        ...              ...
# 308403  Winter             None
# 308404  Winter             None
# 308405  Winter           Sweden
# 308406  Winter             None
# 308407  Winter             None
#
# [308408 rows x 2 columns]

# %%
# All rows and specific columns with iloc
results2.iloc[:, [1,7]]
# Out:
#           type             team
# 0       Summer             None
# 1       Summer   Jean Montariol
# 2       Summer             None
# 3       Summer  Jeanne Vaussard
# 4       Summer  Jacques Brugnon
# ...        ...              ...
# 308403  Winter             None
# 308404  Winter             None
# 308405  Winter           Sweden
# 308406  Winter             None
# 308407  Winter             None
#
# [308408 rows x 2 columns]

# %%
results2 = pd.read_parquet(r'C:\Users\Walid\Desktop\new file.parquet')
results2.index = results2['type']

# %% [markdown]
# ----

# %% [markdown]
# ### Optional Part

# %%
results2 = pd.read_parquet(r'C:\Users\Walid\Desktop\new file.parquet')
results2.head(1)
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc  team  place  tied medal
# 0           1  FRA  None   17.0  True  None

# %%
# Changing the index
results2.set_index('type', inplace=True)

# %%
results_restored = results2.reset_index()
results_restored
# Out:
#           type    year              discipline                          event  \
# 0       Summer  1912.0                  Tennis         Singles, Men (Olympic)
# 1       Summer  1912.0                  Tennis         Doubles, Men (Olympic)
# 2       Summer  1920.0                  Tennis         Singles, Men (Olympic)
# 3       Summer  1920.0                  Tennis       Doubles, Mixed (Olympic)
# 4       Summer  1920.0                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  Winter  2022.0                    Luge         Singles, Men (Olympic)
# 308404  Winter  2022.0  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  Winter  2022.0  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  Winter  2022.0  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  Winter  2022.0                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# ---

# %%
# Using loc from the new index
results2.loc['Summer']
# Out:
#           year    type                      discipline  \
# type
# Summer  1912.0  Summer                          Tennis
# Summer  1912.0  Summer                          Tennis
# Summer  1920.0  Summer                          Tennis
# Summer  1920.0  Summer                          Tennis
# Summer  1920.0  Summer                          Tennis
# ...        ...     ...                             ...
# Summer  1996.0  Summer           Water Polo (Aquatics)
# Summer  1920.0  Summer                          Rowing
# Summer  2018.0  Summer  Roller Skating (Roller Sports)
# Summer  2018.0  Summer                       Triathlon
# Summer  2018.0  Summer                       Triathlon
#
#                              event                        as  athlete_id  noc  \
# type
# Summer      Singles, Men (Olympic)     Jean-François Blanchy           1  FRA
# Summer      Doubles, Men (Olympic)     Jean-François Blanchy           1  FRA
# ...

# %%
# Multple filters
results2.loc['Summer', 'medal']
# Out:
# type
# Summer      None
# Summer      None
# Summer      None
# Summer      None
# Summer      None
#            ...
# Summer      None
# Summer      None
# Summer    Bronze
# Summer    Bronze
# Summer      Gold
# Name: medal, Length: 241298, dtype: object

# %%
# Modification of specific value
results2 = pd.read_parquet(r'C:\Users\Walid\Desktop\new file.parquet')
results2.loc[0]
# Out:
# year                          1912.0
# type                          Summer
# discipline                    Tennis
# event         Singles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                            None
# place                           17.0
# tied                            True
# medal                           None
# Name: 0, dtype: object

# %%
results2.loc[0,"year"] = 1958 # I will always remember you

# %%
results2.loc[0]
# Out:
# year                          1958.0
# type                          Summer
# discipline                    Tennis
# event         Singles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                            None
# place                           17.0
# tied                            True
# medal                           None
# Name: 0, dtype: object

# %%
# Using at and iat rather than loc and iloc
#at
results2.at[0, "discipline"]
# Out:
# 'Tennis'

# %%
#iat
results2.iat[0,2]
# Out:
# 'Tennis'

# %%
#access data for specific column
results.type
# Out:
# 0         Summer
# 1         Summer
# 2         Summer
# 3         Summer
# 4         Summer
#            ...
# 308403    Winter
# 308404    Winter
# 308405    Winter
# 308406    Winter
# 308407    Winter
# Name: type, Length: 308408, dtype: object

# %%
results['type']
# Out:
# 0         Summer
# 1         Summer
# 2         Summer
# 3         Summer
# 4         Summer
#            ...
# 308403    Winter
# 308404    Winter
# 308405    Winter
# 308406    Winter
# 308407    Winter
# Name: type, Length: 308408, dtype: object

# %%
# Sort the data (ascending order)
results2.sort_values('athlete_id')
# Out:
#           year    type              discipline                          event  \
# type
# Summer  1912.0  Summer                  Tennis         Singles, Men (Olympic)
# Summer  1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# Summer  1920.0  Summer                  Tennis         Singles, Men (Olympic)
# Summer  1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# Summer  1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# Winter  2022.0  Winter                    Luge         Singles, Men (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# Winter  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
# Decending order
results2.sort_values('athlete_id', ascending = False)
# Out:
#           year    type              discipline                          event  \
# type
# Winter  2022.0  Winter                    None        Slalom, Women (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# Winter  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# Winter  2022.0  Winter                    Luge         Singles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# Summer  1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# Summer  1920.0  Summer                  Tennis         Singles, Men (Olympic)
# Summer  1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# Summer  1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# Summer  1912.0  Summer                  Tennis         Singles, Men (Olympic)
#
# ...

# %%
# Sort by multiple parameters
results2.sort_values(['year','place'], ascending = False)
# Out:
#           year    type                     discipline  \
# type
# Winter  2022.0  Winter  Cross Country Skiing (Skiing)
# Winter  2022.0  Winter  Cross Country Skiing (Skiing)
# Winter  2022.0  Winter  Cross Country Skiing (Skiing)
# Winter  2022.0  Winter  Cross Country Skiing (Skiing)
# Winter  2022.0  Winter                       Biathlon
# ...        ...     ...                            ...
# None       NaN    None            Football (Football)
# None       NaN    None                         Rowing
# None       NaN    None                         Rowing
# None       NaN    None            Football (Football)
# None       NaN    None            Football (Football)
#
#                                            event                       as  \
# type
# Winter            10 kilometres, Women (Olympic)              Nefeli Tita
# Winter            10 kilometres, Women (Olympic)               Sára Pónya
# Winter            10 kilometres, Women (Olympic)             Nahiara Díaz
# ...

# %%
# Sort by multiple parameters (different order)
results2.sort_values(['year','place'], ascending = [0,1])
# Out:
#           year    type                           discipline  \
# type
# Winter  2022.0  Winter              Speed Skating (Skating)
# Winter  2022.0  Winter  Short Track Speed Skating (Skating)
# Winter  2022.0  Winter  Short Track Speed Skating (Skating)
# Winter  2022.0  Winter                Snowboarding (Skiing)
# Winter  2022.0  Winter                Snowboarding (Skiing)
# ...        ...     ...                                  ...
# None       NaN    None                  Football (Football)
# None       NaN    None                               Rowing
# None       NaN    None                               Rowing
# None       NaN    None                  Football (Football)
# None       NaN    None                  Football (Football)
#
#                                            event                       as  \
# type
# Winter             1,500 metres, Women (Olympic)               Ireen Wüst
# Winter         5,000 metres Relay, Men (Olympic)          Charles Hamelin
# ...
